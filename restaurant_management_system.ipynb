# %%
import random 
# Global List Declaration 
name = [] 
phno = [] 
rb = [] 
item = []
Token = []
# Global Vaariable Declaration 
i= 0

# %%
def Home(): 	
	print("\t\t\t\t\t\t WELCOME TO HOTEL Chillox\n") 
	print("\t\t\t 1 Take A Token Number \n") 
	print("\t\t\t 2 Menu Card\n") 
	print("\t\t\t 3 Payment\n") 
	print("\t\t\t 0 Exit\n") 

	ch=int(input("->")) 
	
	if ch == 1: 
		print(" ") 
		Token_no() 
	
	elif ch == 2: 
		print(" ") 
		Menu_Card() 
	
	elif ch == 3: 
		print(" ") 
		Payment() 
	else: 
		exit()

# %%
def Token_no(): 
  global i
  print("Take A Token Number")

  while 1:
    na = str(input("Name : "))
    p1 = str(input("Phone No. : "))

    if na!="" and p1!="":
      name.append(na)
      phno.append(p1)
      break
    else:
      print("\tName, Phone no. cannot be empty..!!")

  rn = random.randrange(50) 
  print("Token Number - ",rn) 
  Token.append(rn)
  i=i+1
  n=int(input("0-BACK\n ->")) 
  if n==0: 
    Home() 
  else: 
    exit()

# %%
def Menu_Card(): 
    tn=int(input("Token Number: ")) 
    global i 
    f=0
    s=0
    rb.append(0)
    for n in range(0,i): 
        if Token[n]==tn: 
            f=1
            print("-----------------------------------------------------------------------------------") 
            print("                                    Chillox") 
            print("-----------------------------------------------------------------------------------") 
            print("                                   Menu Card") 
            print("-------------------------------------------------------------------------") 
            print("\n__________BEEF BURGERS___________          ____________CHICKEN BURGERS____________") 
            print("````````````````````````````````````````````````````````````````````````````````````") 
            print(" 1  Beep Burger............. BDT: 160.00  |  7 Chicken Burger............BDT: 160.00") 
            print(" 2  Beep Cheese............. BDT: 180.00  |  8 Chicken Cheese............BDT: 180.00") 
            print(" 3  Beep With Bacon......... BDT: 210.00  |  9 Chicken With Bacon........BDT: 210.00") 
            print(" 4  Beep Signature.......... BDT: 330.00  |  10 chicken Signature........BDT: 330.00") 
            print(" 5  Giganto Beep............ BDT: 390.00  |  11 Giganto chicken..........BDT: 390.00") 
            print(" 6  Binge Beep.............. BDT: 620.00  |  12 Binge chicken............BDT: 620.00") 
            print("\n__________NAGA DRUMS____________            __________Refreshment Drinks__________")
            print("````````````````````````````````````````````````````````````````````````````````````")
            print(" 13 1 Pcs....................BDT: 90.00   |  15 Roy Rogers.............. BDT: 100.00")
            print(" 14 2 Pcs....................BDT: 160.00  |  16 Rancho lemonade......... BDT: 100.00")
            print("                                          |  17 Aqua Fresca............. BDT: 120.00")  
            print("____________Shakes________________        |  18 Green Appel Rush........ BDT: 140.00")
            print("21 Cold Coffee...............BDT: 120.00  |  19 Strawberry squeeze...... BDT: 140.00")
            print("22 Munch.....................BDT: 120.00  |  20 Blackberry Bounce....... BDT: 140.00")
            print("23 Oreo......................BDT: 140.00  |  ```````````````````````````````````````")
            print("24 Mars......................BDT: 150.00  |  ```````````````````````````````````````")
            print("25 Nutella...................BDT: 150.00  |  ``````````````` Chill ``````````````````")
            print("26 Snickers..................BDT: 150.00  |  ````````````````` with Chillox ````````")
            print("27 ferrero rocher............BDT: 160.00  |  ```````````````````````````````````````")
            print("28 Shamrock..................BDT: 160.00  |  ```````````````````````````````````````")      

            print("________________________________Press 0 -to end_____________________________________") 
          
            ch=1
            while(ch!=0): 
                  
                ch=int(input(" -> ")) 
                  
                # if-elif-conditions to assign item 
                # prices listed in menu card 
                if ch==1 or ch==7 or ch==14 or ch==27 or ch==28 : 
                  BDT=160.00
                  s=s+BDT 
                  if ch==1:
                    item.append('Beep Burger ..............................BDT: 160.00')
                  elif ch==7:
                    item.append('Chicken Burger............................BDT: 160.00')
                  elif ch==14:
                    item.append('Naga drums 2 Pcs..........................BDT: 160.00')
                  elif ch==27:
                    item.append('ferrero rocher............................BDT: 160.00')
                  elif ch==28:
                    item.append('Shamrock..................................BDT: 160.00')
                  else:
                    print("None")
                elif ch==2 or ch==8:
                  BDT=180.00
                  s=s+BDT
                  if ch==2:
                    item.append('Beep Cheese...............................BDT: 180.00')
                  elif ch==8:
                    item.append('Chicken Cheese............................BDT: 180.00')
                  else:
                    print("None")
                elif ch==3 or ch==9:
                  BDT=210.00
                  s=s+BDT
                  if ch==3:
                    item.append('Beep With Bacon...........................BDT: 210.00')
                  elif ch==9:
                    item.append('Chicken With Bacon........................BDT: 210.00')
                  else:
                    print("None")
                elif ch==4 or ch==10:
                  BDT=330.00
                  s=s+BDT
                  if ch==4:
                    item.append('Beep Signature............................BDT: 330.00')
                  elif ch==10:
                    item.append('Chicken Signature.........................BDT: 330.00')
                  else:
                    print("None")
                elif ch==5 or ch==11:
                    BDT=390.00
                    s=s+BDT
                    if ch==5:
                      item.append('Giganto Beep............................ BDT:390.00')
                    elif ch==11:
                      item.append('Giganto chicken..........................BDT:390.00')
                    else:
                      print("None")
                elif ch==6 or ch==12:
                   BDT=620.00
                   s=s+BDT
                   if ch==6:
                     item.append('Binge Beep.............................. BDT: 390.00')
                   elif ch==12:
                     item.append('Binge chicken............................BDT: 390.00')
                   else:
                     print("None")
                elif ch==13:
                  BDT=90.00
                  s=s+BDT
                  if ch==13:
                    item.append('Naga Drums 1 pcs..........................BDT: 90.00')
                elif ch==15 or ch==16:
                  BDT=100.00
                  s=s+BDT
                  if ch==15:
                    item.append('Roy Rogers............................... BDT: 100.00')
                  elif ch==16:
                    item.append('Rancho lemonade.......................... BDT: 100.00')
                  else:
                    print("None")
                elif ch==17 or ch==21 or ch==22:
                  BDT=120.00
                  s=s+BDT
                  if ch==17:
                    item.append('Aqua Fresca.............................. BDT: 120.00')
                  elif ch==21:
                    item.append('Cold Coffee...............................BDT: 120.00')
                  elif ch==22:
                    item.append('Munch.....................................BDT: 120.00')
                  else:
                    print("None")
                elif ch==18 or ch==19 or ch==20 or ch==23: 
                  BDT=140.00
                  s=s+BDT 
                  if ch==18:
                    item.append('Green Appel Rush......................... BDT: 140.00')
                  elif ch==19:
                    item.append('Strawberry squeeze....................... BDT: 140.00')
                  elif ch==20:
                    item.append('Blackberry Bounce........................ BDT: 140.00')
                  elif ch==23:
                    item.append('Oreo......................................BDT: 140.00')
                  else:
                    print("None")
                elif ch==24 or ch==25 or ch==26:
                  BDT=150.00
                  s=s+BDT
                  if ch==24:
                    item.append('Mars......................................BDT: 150.00')
                  elif ch==25:
                    item.append('Nutella...................................BDT: 150.00')
                  elif ch==26:
                    item.append('Snickers..................................BDT: 150.00')
                  else:
                    print("None")
                elif ch==0: 
                    pass
                else: 
                    print("Wrong Choice..!!") 
            print("Total Bill: ",s)    
            
            # updates restaurant bill and then  
            # appends in 'rb' list 
            s=s+rb.pop(n) 
            rb.append(s)     
        else: 
            pass
    if f == 0: 
        print("Invalid Token Number") 
    n=int(input("0-BACK\n ->")) 
    if n==0: 
        Home() 
    else: 
        exit()

# %%
def Payment(): 
    tn=int(input("Token Number: ")) 
    global i 
    f=0
    for n in range(0,i): 
        if Token[n]==tn: 
            f=1                 
            print(" Payment") 
            print(" --------------------------------") 
            print("  MODE OF PAYMENT") 
              
            print("  1- Credit/Debit Card") 
            print("  2- Paytm/PhonePe") 
            print("  3- Using UPI") 
            print("  4- Cash") 
            x=int(input("-> ")) 
            print("\n  Total Amount: ",(rb[n]))
            print("\n  Pay For Chillox") 
            print("  (y/n)") 
            ch=str(input("->"))

            if ch=='y' or ch=='Y': 
              print("\n\n -----------------------------------------------") 
              print("                     Chillox") 
              print(" ---------------------------------------------------") 
              print("                   Order Detail") 
              print(" ---------------------------------------------------") 
              print("Name: ",*name, sep=' ') 
              print("Phone No.: ",*phno,sep=' ') 
              print("Item : ",*item,sep='\n')
              print(" ---------------------------------------------------")
              print("Total Bill                                BDT:",rb[n]) 
              print(" ---------------------------------------------------") 
              print("                    Thank You") 
              print("                   Visit Again") 
              print(" -------------------------------------------------\n")
              name.clear()
              phno.clear()
              item.clear()
    if f == 0: 
        print("Invalid Token Number") 
    n=int(input("0-BACK\n ->")) 
    if n==0: 
        Home() 
    else: 
        exit()

# %%
Home()
# Out:
# 						 WELCOME TO HOTEL Chillox
#
# 			 1 Take A Token Number
#
# 			 2 Menu Card
#
# 			 3 Payment
#
# 			 0 Exit
#
# ->1
#
# Take A Token Number
# Name : Tohin
# Phone No. : 01777305810
# Token Number -  44
# 0-BACK
#  ->0
# 						 WELCOME TO HOTEL Chillox
#
# 			 1 Take A Token Number
#
# 			 2 Menu Card
#
# 			 3 Payment
#
# 			 0 Exit
#
# ->2
#
# Token Number: 44
# -----------------------------------------------------------------------------------
#                                     Chillox
# -----------------------------------------------------------------------------------
#                                    Menu Card
# -------------------------------------------------------------------------
#
# __________BEEF BURGERS___________          ____________CHICKEN BURGERS____________
# ````````````````````````````````````````````````````````````````````````````````````
#  1  Beep Burger............. BDT: 160.00  |  7 Chicken Burger............BDT: 160.00
# ...
